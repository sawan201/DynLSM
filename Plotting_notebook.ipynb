# %%
from ramsay_diagnostics import interactive_latent_trajectory
fig = interactive_latent_trajectory(
          file   = "sim_run.npz",
          burn   = 1000,
          actor  = 2,
          time   = 0,
          stride = 10)
fig.show()
